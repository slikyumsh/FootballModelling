# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import random
import numpy as np

from classes import *

# %%
paths = PathsInputOutput("backgrounds/resized_simple_field.jpg", "backgrounds/simple_field_output.jpg")
field = Field(paths, 10, 10)
football_field = FootballField(field)
team1 = [40, 21, 41, 61, 81, 52, 43, 63, 24, 84, 54]
team2 = [49, 28, 48, 68, 88, 57, 46, 66, 25, 85, 55]
football_field.add_two_teams(team1, team2)
model = Model(football_field)
model.run()
# Out:
# Input image:  backgrounds/resized_simple_field.jpg
# Output image:  backgrounds/simple_field_output.jpg
