# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import random
import numpy as np

from class_second_version import *

# %%
paths = PathsInputOutput("backgrounds/resized_simple_field.jpg", "backgrounds/simple_field_output.jpg")
field = Field(paths)
football_field = FootballField(field)
team1 = []
team2 = []

player = Player(1, 10, True)
position = Position(50, 500)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(200, 200)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(200, 400)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(200, 600)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(200, 800)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(350, 500)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(450, 350)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(450, 650)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(700, 500)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(650, 200)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(650, 800)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

# %%
player = Player(2, 0, True)
position = Position(1450, 500)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(1300, 800)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(1300, 600)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(1300, 400)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(1300, 200)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(1150, 500)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(1050, 650)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(1050, 350)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(800, 500)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(850, 800)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 0, False)
position = Position(850, 200)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

# %%
football_field.add_two_teams(team1, team2)

# %%
football_field.show_pic_with_players()

# %%
football_field1 = copy.deepcopy(football_field)
football_field2 = copy.deepcopy(football_field)

# %%
model1 = Model(copy.deepcopy(football_field), copy.deepcopy(team1[2]), 40, 300, 200, 0.8)

# %%
model2 = Model(copy.deepcopy(football_field), copy.deepcopy(team1[2]), 40, 200, 200, 0.85)
model3 = Model(copy.deepcopy(football_field), copy.deepcopy(team1[2]), 40, 100, 200, 0.95)

# %%
exp = Experiment([model1, model2, model3], 0)

# %%
exp.create_param_variations("beta", 10, 100)
exp.run()
# Out:
# Results saved to experiment_results\football_0_02_07_2024_20-23-55.csv

# %%
import pandas as pd
data = pd.read_csv("experiment_results/football_0_02_07_2024_20-23-55.csv")
data
# Out:
#                                      input_information  unique_players  \
# 0    {"field": {"field": {"paths": {"background_ima...               4
# 1    {"field": {"field": {"paths": {"background_ima...               6
# 2    {"field": {"field": {"paths": {"background_ima...               3
# 3    {"field": {"field": {"paths": {"background_ima...               3
# 4    {"field": {"field": {"paths": {"background_ima...               6
# ..                                                 ...             ...
# 295  {"field": {"field": {"paths": {"background_ima...               6
# 296  {"field": {"field": {"paths": {"background_ima...               6
# 297  {"field": {"field": {"paths": {"background_ima...               3
# 298  {"field": {"field": {"paths": {"background_ima...               5
# 299  {"field": {"field": {"paths": {"background_ima...               5
#
#      passes  iterations  final_xg
# 0         3         201  0.618659
# 1         7         201  0.630411
# ...
