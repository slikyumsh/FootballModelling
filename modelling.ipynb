# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import random

from class_second_version import *

# %%
paths = PathsInputOutput("backgrounds/resized_simple_field.jpg", "backgrounds/simple_field_output.jpg")
field = Field(paths)
football_field = FootballField(field)
team1 = []
team2 = []

player = Player(1, 0, True)
position = Position(50, 500)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 40, False)
position = Position(200, 200)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(200, 400)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(200, 600)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 40, False)
position = Position(200, 800)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 30, False)
position = Position(350, 500)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 30, False)
position = Position(450, 350)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 30, False)
position = Position(450, 650)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 50, False)
position = Position(700, 500)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 50, False)
position = Position(650, 200)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 50, False)
position = Position(650, 800)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

# %%
player = Player(2, 0, True)
position = Position(1450, 500)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1300, 800)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1300, 600)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1300, 400)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1300, 200)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1150, 500)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1050, 650)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1050, 350)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(800, 500)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(850, 800)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(850, 200)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

# %%
football_field.add_two_teams(team1, team2)

# %%
football_field1 = copy.deepcopy(football_field)
football_field2 = copy.deepcopy(football_field)

# %%
model1 = Model(copy.deepcopy(football_field), copy.deepcopy(team1[2]), 2, 1.5, 100, 0.95)

# %%
model2 = Model(copy.deepcopy(football_field), copy.deepcopy(team1[2]), 2, 1.5, 100, 0.95)

# %%
exp = Experiment([model1, model2], 0)

# %%
exp.create_param_variations("beta", 10, 20)
exp.run()
# Out:
# Results saved to experiment_results\football_0_23_07_2024_15-13-32.csv

# %%
exp.models[0].metropolis()
# Out:
# Cur player:  103
# Partners number:  7
# Accepted full
# Iteration 0: Positions recorded
# Cur player:  107
# Partners number:  9
# Accepted part
# Iteration 1: Positions recorded
# Cur player:  102
# Partners number:  9
# Accepted full
# Iteration 2: Positions recorded
# Cur player:  110
# Partners number:  9
# Accepted part
# Iteration 3: Positions recorded
# Cur player:  103
# Partners number:  9
# Accepted full
# Iteration 4: Positions recorded
# Cur player:  106
# Partners number:  7
# Accepted part
# Iteration 5: Positions recorded
# Cur player:  104
# Partners number:  9
# Accepted full
# Iteration 6: Positions recorded
# Cur player:  109
# Partners number:  8
# Accepted part
# Iteration 7: Positions recorded
# Cur player:  107
# Partners number:  9
# Accepted full
# Iteration 8: Positions recorded
# Cur player:  109
# Partners number:  7
# Accepted part
# Iteration 9: Positions recorded
# Cur player:  102
# Partners number:  9
# Accepted full
# Iteration 10: Positions recorded
# Cur player:  110
# Partners number:  8
# Accepted part
# Iteration 11: Positions recorded
# Cur player:  103
# Partners number:  9
# Accepted full
# Iteration 12: Positions recorded
# Cur player:  110
# Partners number:  8
# Accepted full
# Iteration 13: Positions recorded
# Cur player:  106
# Partners number:  9
# Accepted full
# Iteration 14: Positions recorded
# Cur player:  108
# Partners number:  9
# Accepted part
# Iteration 15: Positions recorded
# Cur player:  106
# Partners number:  8
# Accepted part
# Iteration 16: Positions recorded
# Cur player:  103
# Partners number:  9
# Accepted part
# Iteration 17: Positions recorded
# Cur player:  102
# Partners number:  9
# Accepted full
# Iteration 18: Positions recorded
# Cur player:  103
# Partners number:  9
# Accepted part
# Iteration 19: Positions recorded
# Cur player:  105
# Partners number:  9
# Accepted full
# Iteration 20: Positions recorded
# Cur player:  104
# Partners number:  7
# Accepted full
# Iteration 21: Positions recorded
# Cur player:  108
# Partners number:  9
# Accepted part
# Iteration 22: Positions recorded
# Cur player:  102
# Partners number:  8
# Accepted full
# Iteration 23: Positions recorded
# Cur player:  103
# Partners number:  9
# Accepted full
# Iteration 24: Positions recorded
# Cur player:  111
# Partners number:  9
# Accepted full
# Iteration 25: Positions recorded
# Cur player:  110
# Partners number:  8
# Accepted part
# Iteration 26: Positions recorded
# Cur player:  103
# Partners number:  9
# Accepted part
# Iteration 27: Positions recorded
# Cur player:  102
# Partners number:  7
# Accepted full
# Iteration 28: Positions recorded
# Cur player:  104
# Partners number:  8
# Accepted full
# Iteration 29: Positions recorded
# Cur player:  110
# Partners number:  9
# Accepted full
# Iteration 30: Positions recorded
# Cur player:  109
# Partners number:  9
# Accepted part
# Iteration 31: Positions recorded
# Cur player:  105
# Partners number:  9
# Accepted full
# Iteration 32: Positions recorded
# Cur player:  110
# Partners number:  8
# Accepted part
# Iteration 33: Positions recorded
# Cur player:  108
# Partners number:  7
# Accepted full
# Iteration 34: Positions recorded
# Cur player:  109
# Partners number:  7
# Accepted part
# Iteration 35: Positions recorded
# Cur player:  108
# Partners number:  8
# Accepted part
# Iteration 36: Positions recorded
# Cur player:  105
# Partners number:  8
# Accepted full
# Iteration 37: Positions recorded
# Cur player:  110
# Partners number:  8
# Accepted part
# Iteration 38: Positions recorded
# Cur player:  107
# Partners number:  7
# Accepted part
# Iteration 39: Positions recorded
# Cur player:  108
# Partners number:  5
# Accepted part
# Iteration 40: Positions recorded
# Cur player:  105
# Partners number:  7
# Accepted full
# Iteration 41: Positions recorded
# Cur player:  102
# Partners number:  7
# Accepted full
# Iteration 42: Positions recorded
# Cur player:  108
# Partners number:  7
# Accepted part
# Iteration 43: Positions recorded
# Cur player:  102
# Partners number:  8
# Accepted full
# Iteration 44: Positions recorded
# Cur player:  106
# Partners number:  7
# Accepted part
# Iteration 45: Positions recorded
# Cur player:  108
# Partners number:  8
# Accepted full
# Iteration 46: Positions recorded
# Cur player:  107
# Partners number:  8
# Accepted part
# Iteration 47: Positions recorded
# Cur player:  108
# Partners number:  7
# Accepted full
# Iteration 48: Positions recorded
# Cur player:  107
# Partners number:  7
# Accepted full
# Iteration 49: Positions recorded
# Cur player:  106
# Partners number:  7
# Accepted part
# Iteration 50: Positions recorded
# Cur player:  105
# Partners number:  7
# Accepted full
# Iteration 51: Positions recorded
# Cur player:  102
# Partners number:  7
# Accepted part
# Iteration 52: Positions recorded
# Cur player:  103
# Partners number:  7
# Accepted full
# Iteration 53: Positions recorded
# Cur player:  106
# Partners number:  7
# Accepted part
# Iteration 54: Positions recorded
# Cur player:  102
# Partners number:  6
# Accepted full
# Iteration 55: Positions recorded
# Cur player:  108
# Partners number:  7
# Accepted full
# Iteration 56: Positions recorded
# Cur player:  106
# Partners number:  8
# Accepted part
# Iteration 57: Positions recorded
# Cur player:  102
# Partners number:  7
# Accepted part
# Iteration 58: Positions recorded
# Cur player:  104
# Partners number:  5
# Accepted part
# Iteration 59: Positions recorded
# Cur player:  105
# Partners number:  6
# Accepted full
# Iteration 60: Positions recorded
# Cur player:  107
# Partners number:  7
# Accepted part
# Iteration 61: Positions recorded
# Cur player:  108
# Partners number:  5
# Accepted part
# Iteration 62: Positions recorded
# Cur player:  104
# Partners number:  5
# Accepted part
# Iteration 63: Positions recorded
# Cur player:  103
# Partners number:  5
# Accepted full
# Iteration 64: Positions recorded
# Cur player:  107
# Partners number:  5
# Accepted part
# Iteration 65: Positions recorded
# Cur player:  108
# Partners number:  7
# Accepted part
# Iteration 66: Positions recorded
# Cur player:  104
# Partners number:  5
# Accepted part
# Iteration 67: Positions recorded
# Cur player:  105
# Partners number:  5
# Accepted full
# Iteration 68: Positions recorded
# Cur player:  102
# Partners number:  5
# Accepted part
# Iteration 69: Positions recorded
# Cur player:  103
# Partners number:  5
# Accepted full
# Iteration 70: Positions recorded
# Cur player:  104
# Partners number:  6
# Accepted full
# Iteration 71: Positions recorded
# Cur player:  107
# Partners number:  7
# Accepted full
# Iteration 72: Positions recorded
# Cur player:  109
# Partners number:  6
# Accepted part
# Iteration 73: Positions recorded
# Cur player:  105
# Partners number:  5
# Accepted full
# Iteration 74: Positions recorded
# Cur player:  106
# Partners number:  6
# Accepted part
# Iteration 75: Positions recorded
# Cur player:  102
# Partners number:  6
# Accepted part
# Iteration 76: Positions recorded
# Cur player:  105
# Partners number:  5
# Accepted full
# Iteration 77: Positions recorded
# Cur player:  102
# Partners number:  6
# Accepted part
# Iteration 78: Positions recorded
# Cur player:  104
# Partners number:  6
# Accepted full
# Iteration 79: Positions recorded
# Cur player:  106
# Partners number:  5
# Accepted part
# Iteration 80: Positions recorded
# Cur player:  102
# Partners number:  4
# Accepted part
# Iteration 81: Positions recorded
# Cur player:  105
# Partners number:  5
# Accepted full
# Iteration 82: Positions recorded
# Cur player:  103
# Partners number:  5
# Accepted part
# Iteration 83: Positions recorded
# Cur player:  105
# Partners number:  5
# Accepted full
# Iteration 84: Positions recorded
# Cur player:  102
# Partners number:  5
# Accepted full
# Iteration 85: Positions recorded
# Cur player:  106
# Partners number:  5
# Accepted part
# Iteration 86: Positions recorded
# Cur player:  102
# Partners number:  5
# Accepted full
# Iteration 87: Positions recorded
# Cur player:  106
# Partners number:  5
# Accepted part
# Iteration 88: Positions recorded
# Cur player:  102
# Partners number:  5
# Accepted full
# Iteration 89: Positions recorded
# Cur player:  107
# Partners number:  3
# Accepted full
# Iteration 90: Positions recorded
# Cur player:  106
# Partners number:  5
# Accepted part
# Iteration 91: Positions recorded
# Cur player:  103
# Partners number:  4
# Accepted full
# Iteration 92: Positions recorded
# Cur player:  106
# Partners number:  4
# Accepted part
# Iteration 93: Positions recorded
# Cur player:  104
# Partners number:  5
# Accepted full
# Iteration 94: Positions recorded
# Cur player:  107
# Partners number:  4
# Accepted part
# Iteration 95: Positions recorded
# Cur player:  103
# Partners number:  5
# Accepted full
# Iteration 96: Positions recorded
# Cur player:  107
# Partners number:  5
# Accepted part
# Iteration 97: Positions recorded
# Cur player:  105
# Partners number:  5
# Accepted full
# Iteration 98: Positions recorded
# Cur player:  106
# Partners number:  5
# Accepted part
# Iteration 99: Positions recorded

# %%
exp.models[0].create_gif()
# Out:
# GIF сохранен по пути dynamics/player_positions_2c731adb-2959-465b-9c70-ddbfec170642.gif

# %%
import pandas as pd
data = pd.read_csv("experiment_results/football_0_23_07_2024_14-56-15.csv")
data.head()
# Out:
#                                    input_information  unique_players  passes  \
# 0  {"field": {"field": {"paths": {"background_ima...              10      99
# 1  {"field": {"field": {"paths": {"background_ima...              10      86
# 2  {"field": {"field": {"paths": {"background_ima...               7      31
# 3  {"field": {"field": {"paths": {"background_ima...               6      17
# 4  {"field": {"field": {"paths": {"background_ima...               6      15
#
#    iterations  final_xg
# 0         101  0.291462
# 1         101  0.569737
# 2         101  0.918472
# 3         101  0.691460
# 4         101  0.642806
