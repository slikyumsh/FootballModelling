# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import random
import numpy as np

from class_second_version import *

# %%
paths = PathsInputOutput("backgrounds/resized_simple_field.jpg", "backgrounds/simple_field_output.jpg")
field = Field(paths)
football_field = FootballField(field)
team1 = []
team2 = []

player = Player(1, 0, True)
position = Position(50, 500)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 40, False)
position = Position(200, 200)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(200, 400)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 10, False)
position = Position(200, 600)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 40, False)
position = Position(200, 800)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 30, False)
position = Position(350, 500)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 30, False)
position = Position(450, 350)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 30, False)
position = Position(450, 650)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 50, False)
position = Position(700, 500)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 50, False)
position = Position(650, 200)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

player = Player(1, 50, False)
position = Position(650, 800)
playerOnField = PlayerOnField(player, position)
team1.append(playerOnField)

# %%
player = Player(2, 0, True)
position = Position(1450, 500)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1300, 800)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1300, 600)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1300, 400)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1300, 200)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1150, 500)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1050, 650)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(1050, 350)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(800, 500)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(850, 800)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

player = Player(2, 10, False)
position = Position(850, 200)
playerOnField = PlayerOnField(player, position)
team2.append(playerOnField)

# %%
football_field.add_two_teams(team1, team2)

# %%
football_field1 = copy.deepcopy(football_field)
football_field2 = copy.deepcopy(football_field)

# %%
model1 = Model(copy.deepcopy(football_field), copy.deepcopy(team1[2]), 4, 1.5, 100, 0.95)

# %%
model2 = Model(copy.deepcopy(football_field), copy.deepcopy(team1[2]), 4, 1.5, 100, 0.95)

# %%
exp = Experiment([model1, model2], 0)

# %%
exp.create_param_variations("beta", 10, 20)
exp.run()
# Out:
# Results saved to experiment_results\football_0_23_07_2024_13-54-50.csv

# %%
exp.models[0].metropolis()
# Out:
# Cur player:  103
# Partners number:  7
# Accepted full
# Iteration 0: Positions recorded
# Cur player:  108
# Partners number:  9
# Accepted part
# Iteration 1: Positions recorded
# Cur player:  104
# Partners number:  8
# Accepted part
# Iteration 2: Positions recorded
# Cur player:  102
# Partners number:  9
# Accepted full
# Iteration 3: Positions recorded
# Cur player:  111
# Partners number:  9
# Accepted part
# Iteration 4: Positions recorded
# Cur player:  102
# Partners number:  8
# Accepted full
# Iteration 5: Positions recorded
# Cur player:  104
# Partners number:  9
# Accepted full
# Iteration 6: Positions recorded
# Cur player:  110
# Partners number:  8
# Accepted part
# Iteration 7: Positions recorded
# Cur player:  107
# Partners number:  8
# Accepted part
# Iteration 8: Positions recorded
# Cur player:  108
# Partners number:  8
# Accepted full
# Iteration 9: Positions recorded
# Cur player:  110
# Partners number:  9
# Accepted part
# Iteration 10: Positions recorded
# Cur player:  108
# Partners number:  8
# Accepted full
# Iteration 11: Positions recorded
# Cur player:  106
# Partners number:  9
# Accepted part
# Iteration 12: Positions recorded
# Cur player:  111
# Partners number:  8
# Accepted part
# Iteration 13: Positions recorded
# Cur player:  105
# Partners number:  8
# Accepted part
# Iteration 14: Positions recorded
# Cur player:  111
# Partners number:  8
# Accepted part
# Iteration 15: Positions recorded
# Cur player:  102
# Partners number:  8
# Accepted full
# Iteration 16: Positions recorded
# Cur player:  105
# Partners number:  8
# Accepted full
# Iteration 17: Positions recorded
# Cur player:  108
# Partners number:  8
# Accepted full
# Iteration 18: Positions recorded
# Cur player:  109
# Partners number:  7
# Accepted part
# Iteration 19: Positions recorded
# Cur player:  104
# Partners number:  9
# Accepted full
# Iteration 20: Positions recorded
# Cur player:  111
# Partners number:  8
# Accepted full
# Iteration 21: Positions recorded
# Cur player:  110
# Partners number:  7
# Accepted part
# Iteration 22: Positions recorded
# Cur player:  102
# Partners number:  8
# Accepted full
# Iteration 23: Positions recorded
# Cur player:  107
# Partners number:  6
# Accepted full
# Iteration 24: Positions recorded
# Cur player:  109
# Partners number:  9
# Accepted part
# Iteration 25: Positions recorded
# OFFSIDE:  1  X:  1216.812325834039  Enemy player X  1191.4960958764127
# Cur player:  104
# Partners number:  6
# Accepted full
# Iteration 26: Positions recorded
# OFFSIDE:  1  X:  1248.8877648287366  Enemy player X  1194.7174877326975
# Cur player:  106
# Partners number:  8
# Accepted part
# Iteration 27: Positions recorded
# OFFSIDE:  1  X:  1224.72534040178  Enemy player X  1198.4673538364195
# Cur player:  111
# Partners number:  7
# Accepted part
# Iteration 28: Positions recorded
# OFFSIDE:  1  X:  1269.7799955967278  Enemy player X  1200.2750241293309
# Cur player:  104
# Partners number:  7
# Accepted part
# Iteration 29: Positions recorded
# OFFSIDE:  1  X:  1280.8080845515344  Enemy player X  1207.9195665195668
# Cur player:  103
# Partners number:  7
# Accepted full
# Iteration 30: Positions recorded
# OFFSIDE:  1  X:  1283.1774836321188  Enemy player X  1217.0507459217788
# Cur player:  105
# Partners number:  8
# Accepted part
# Iteration 31: Positions recorded
# OFFSIDE:  1  X:  1280.5885092330477  Enemy player X  1224.1279685275977
# Cur player:  103
# Partners number:  6
# Accepted full
# Iteration 32: Positions recorded
# OFFSIDE:  1  X:  1287.8926152059273  Enemy player X  1233.7005264419688
# Cur player:  107
# Partners number:  7
# Accepted part
# Iteration 33: Positions recorded
# Cur player:  105
# Partners number:  7
# Accepted full
# Iteration 34: Positions recorded
# Cur player:  107
# Partners number:  8
# Accepted full
# Iteration 35: Positions recorded
# OFFSIDE:  1  X:  1275.9734078809545  Enemy player X  1246.1583512823922
# Cur player:  108
# Partners number:  6
# Accepted part
# Iteration 36: Positions recorded
# Cur player:  105
# Partners number:  7
# Accepted part
# Iteration 37: Positions recorded
# Cur player:  104
# Partners number:  8
# Accepted full
# Iteration 38: Positions recorded
# OFFSIDE:  1  X:  1288.4914200401013  Enemy player X  1265.5107882186103
# Cur player:  108
# Partners number:  7
# Accepted part
# Iteration 39: Positions recorded
# OFFSIDE:  1  X:  1285.7797006494359  Enemy player X  1275.2939834313288
# Cur player:  103
# Partners number:  7
# Accepted full
# Iteration 40: Positions recorded
# OFFSIDE:  1  X:  1314.4964944740461  Enemy player X  1278.1892412053162
# Cur player:  107
# Partners number:  7
# Accepted part
# Iteration 41: Positions recorded
# OFFSIDE:  1  X:  1341.8014298141009  Enemy player X  1285.7037869178882
# Cur player:  105
# Partners number:  7
# Accepted full
# Iteration 42: Positions recorded
# Cur player:  110
# Partners number:  5
# Accepted full
# Iteration 43: Positions recorded
# OFFSIDE:  1  X:  1320.5509388195676  Enemy player X  1289.5290584181
# Cur player:  108
# Partners number:  4
# Accepted part
# Iteration 44: Positions recorded
# OFFSIDE:  1  X:  1316.951481197123  Enemy player X  1298.189088447626
# Cur player:  106
# Partners number:  7
# Accepted part
# Iteration 45: Positions recorded
# OFFSIDE:  1  X:  1342.1075932993701  Enemy player X  1305.9744445193464
# Cur player:  102
# Partners number:  7
# Accepted full
# Iteration 46: Positions recorded
# OFFSIDE:  1  X:  1363.1051638016474  Enemy player X  1311.0239492031649
# Cur player:  108
# Partners number:  5
# Accepted part
# Iteration 47: Positions recorded
# Cur player:  103
# Partners number:  8
# Accepted full
# Iteration 48: Positions recorded
# Cur player:  105
# Partners number:  8
# Accepted full
# Iteration 49: Positions recorded
# Cur player:  106
# Partners number:  7
# Accepted part
# Iteration 50: Positions recorded
# OFFSIDE:  1  X:  1392.7964966327997  Enemy player X  1327.080665852765
# Cur player:  107
# Partners number:  7
# Accepted part
# Iteration 51: Positions recorded
# Cur player:  104
# Partners number:  8
# Accepted full
# Iteration 52: Positions recorded
# OFFSIDE:  1  X:  1434.3745061363295  Enemy player X  1332.6513186574593
# Cur player:  110
# Partners number:  8
# Accepted full
# Iteration 53: Positions recorded
# Cur player:  106
# Partners number:  8
# Accepted full
# Iteration 54: Positions recorded
# OFFSIDE:  1  X:  1451.4729550341485  Enemy player X  1341.4833919936227
# Cur player:  108
# Partners number:  6
# Accepted part
# Iteration 55: Positions recorded
# OFFSIDE:  1  X:  1484.8389103621892  Enemy player X  1347.9657526169653
# Cur player:  110
# Partners number:  7
# Accepted full
# Iteration 56: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1357.195557796927
# Cur player:  106
# Partners number:  8
# Accepted part
# Iteration 57: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1358.9335123124745
# Cur player:  105
# Partners number:  7
# Accepted part
# Iteration 58: Positions recorded
# Cur player:  104
# Partners number:  8
# Accepted full
# Iteration 59: Positions recorded
# Cur player:  106
# Partners number:  7
# Accepted full
# Iteration 60: Positions recorded
# Cur player:  108
# Partners number:  6
# Accepted full
# Iteration 61: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1373.4802591082537
# Cur player:  106
# Partners number:  8
# Accepted part
# Iteration 62: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1377.3685193019933
# Cur player:  107
# Partners number:  3
# Accepted part
# Iteration 63: Positions recorded
# OFFSIDE:  1  X:  1488.0117948928382  Enemy player X  1377.59217917866
# Cur player:  104
# Partners number:  7
# Accepted full
# Iteration 64: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1377.6862140961198
# Cur player:  111
# Partners number:  7
# Accepted part
# Iteration 65: Positions recorded
# Cur player:  105
# Partners number:  8
# Accepted full
# Iteration 66: Positions recorded
# OFFSIDE:  1  X:  1492.9725220106288  Enemy player X  1389.1187493486752
# Cur player:  111
# Partners number:  7
# Accepted part
# Iteration 67: Positions recorded
# Cur player:  105
# Partners number:  8
# Accepted full
# Iteration 68: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1397.7417373009284
# Cur player:  106
# Partners number:  8
# Accepted part
# Iteration 69: Positions recorded
# Cur player:  107
# Partners number:  2
# Accepted part
# Iteration 70: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1408.1953776685993
# Cur player:  111
# Partners number:  6
# Accepted full
# Iteration 71: Positions recorded
# OFFSIDE:  1  X:  1472.328200759594  Enemy player X  1416.2932166492672
# OFFSIDE:  1  X:  1436.954020981466  Enemy player X  1416.2932166492672
# Cur player:  106
# Partners number:  6
# Accepted part
# Iteration 72: Positions recorded
# OFFSIDE:  1  X:  1466.3059747974485  Enemy player X  1422.4394673580052
# OFFSIDE:  1  X:  1435.3539986630701  Enemy player X  1422.4394673580052
# OFFSIDE:  1  X:  1431.9259899735127  Enemy player X  1422.4394673580052
# Cur player:  107
# Partners number:  5
# Accepted full
# Iteration 73: Positions recorded
# Cur player:  108
# Partners number:  7
# Accepted part
# Iteration 74: Positions recorded
# OFFSIDE:  1  X:  1488.614231313222  Enemy player X  1425.5074527655581
# OFFSIDE:  1  X:  1438.978727750902  Enemy player X  1425.5074527655581
# Cur player:  107
# Partners number:  5
# Accepted part
# Iteration 75: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1433.4050603988212
# OFFSIDE:  1  X:  1478.940050149099  Enemy player X  1433.4050603988212
# OFFSIDE:  1  X:  1441.0351426885766  Enemy player X  1433.4050603988212
# Cur player:  102
# Partners number:  5
# Accepted full
# Iteration 76: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1434.381767264595
# OFFSIDE:  1  X:  1445.725956931698  Enemy player X  1434.381767264595
# OFFSIDE:  1  X:  1451.6754605406477  Enemy player X  1434.381767264595
# Cur player:  107
# Partners number:  6
# Accepted full
# Iteration 77: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1440.4541151639028
# OFFSIDE:  1  X:  1459.225169697614  Enemy player X  1440.4541151639028
# OFFSIDE:  1  X:  1450.983934315789  Enemy player X  1440.4541151639028
# Cur player:  108
# Partners number:  5
# Accepted part
# Iteration 78: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1450
# OFFSIDE:  1  X:  1492.4588416306185  Enemy player X  1450
# OFFSIDE:  1  X:  1474.4560709669122  Enemy player X  1450
# Cur player:  107
# Partners number:  5
# Accepted full
# Iteration 79: Positions recorded
# Cur player:  108
# Partners number:  4
# Accepted part
# Iteration 80: Positions recorded
# OFFSIDE:  1  X:  1499.739451872865  Enemy player X  1450
# OFFSIDE:  1  X:  1499.2315599157491  Enemy player X  1450
# Cur player:  106
# Partners number:  6
# Accepted full
# Iteration 81: Positions recorded
# OFFSIDE:  1  X:  1484.7334313486617  Enemy player X  1450
# OFFSIDE:  1  X:  1500  Enemy player X  1450
# OFFSIDE:  1  X:  1500  Enemy player X  1450
# Cur player:  108
# Partners number:  6
# Accepted part
# Iteration 82: Positions recorded
# OFFSIDE:  1  X:  1468.3297502403339  Enemy player X  1450
# OFFSIDE:  1  X:  1500  Enemy player X  1450
# OFFSIDE:  1  X:  1500  Enemy player X  1450
# Cur player:  102
# Partners number:  4
# Accepted full
# Iteration 83: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1453.5525028960421
# OFFSIDE:  1  X:  1482.1513796399804  Enemy player X  1453.5525028960421
# OFFSIDE:  1  X:  1500  Enemy player X  1453.5525028960421
# Cur player:  107
# Partners number:  6
# Accepted part
# Iteration 84: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1462.7629517976181
# OFFSIDE:  1  X:  1500  Enemy player X  1462.7629517976181
# Cur player:  104
# Partners number:  7
# Accepted full
# Iteration 85: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1466.9871972150959
# OFFSIDE:  1  X:  1500  Enemy player X  1466.9871972150959
# Cur player:  107
# Partners number:  6
# Accepted full
# Iteration 86: Positions recorded
# OFFSIDE:  1  X:  1477.2102120160425  Enemy player X  1467.1349661026366
# OFFSIDE:  1  X:  1500  Enemy player X  1467.1349661026366
# OFFSIDE:  1  X:  1468.618440817148  Enemy player X  1467.1349661026366
# Cur player:  106
# Partners number:  5
# Accepted part
# Iteration 87: Positions recorded
# Cur player:  103
# Partners number:  8
# Accepted full
# Iteration 88: Positions recorded
# OFFSIDE:  1  X:  1488.5207908918733  Enemy player X  1473.0928154929486
# Cur player:  108
# Partners number:  7
# Accepted part
# Iteration 89: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1471.4745068223053
# Cur player:  105
# Partners number:  5
# Accepted full
# Iteration 90: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1478.6107638220706
# OFFSIDE:  1  X:  1500  Enemy player X  1478.6107638220706
# OFFSIDE:  1  X:  1500  Enemy player X  1478.6107638220706
# Cur player:  104
# Partners number:  6
# Accepted part
# Iteration 91: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1482.9004143145924
# OFFSIDE:  1  X:  1500  Enemy player X  1482.9004143145924
# Cur player:  103
# Partners number:  7
# Accepted full
# Iteration 92: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1483.420946551559
# Cur player:  106
# Partners number:  8
# Accepted full
# Iteration 93: Positions recorded
# OFFSIDE:  1  X:  1495.378486255187  Enemy player X  1488.7306648630333
# OFFSIDE:  1  X:  1498.879386108209  Enemy player X  1488.7306648630333
# Cur player:  108
# Partners number:  7
# Accepted part
# Iteration 94: Positions recorded
# Cur player:  107
# Partners number:  7
# Accepted part
# Iteration 95: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1493.6537457753761
# Cur player:  104
# Partners number:  7
# Accepted full
# Iteration 96: Positions recorded
# Cur player:  107
# Partners number:  8
# Accepted full
# Iteration 97: Positions recorded
# OFFSIDE:  1  X:  1500  Enemy player X  1492.6275600472052
# OFFSIDE:  1  X:  1500  Enemy player X  1492.6275600472052
# Cur player:  108
# Partners number:  6
# Accepted part
# Iteration 98: Positions recorded
# Cur player:  104
# Partners number:  8
# Accepted part
# Iteration 99: Positions recorded

# %%
exp.models[0].create_gif()
# Out:
# GIF saved at dynamics/player_positions_db651d63-64e9-4506-b3ac-c25887e9dabc.gif
